# %% [markdown]
# # Project: Train a Quadcopter How to Fly
#
# Design an agent to fly a quadcopter, and then train it using a reinforcement learning algorithm of your choice!
#
# Try to apply the techniques you have learnt, but also feel free to come up with innovative ideas and test them.

# %% [markdown]
# ## Instructions
#
# Take a look at the files in the directory to better understand the structure of the project.
#
# - `task.py`: Define your task (environment) in this file.
# - `agents/`: Folder containing reinforcement learning agents.
#     - `policy_search.py`: A sample agent has been provided here.
#     - `agent.py`: Develop your agent here.
# - `physics_sim.py`: This file contains the simulator for the quadcopter.  **DO NOT MODIFY THIS FILE**.
#
# For this project, you will define your own task in `task.py`.  Although we have provided a example task to get you started, you are encouraged to change it.  Later in this notebook, you will learn more about how to amend this file.
#
# You will also design a reinforcement learning agent in `agent.py` to complete your chosen task.
#
# You are welcome to create any additional files to help you to organize your code.  For instance, you may find it useful to define a `model.py` file defining any needed neural network architectures.
#
# ## Controlling the Quadcopter
#
# We provide a sample agent in the code cell below to show you how to use the sim to control the quadcopter.  This agent is even simpler than the sample agent that you'll examine (in `agents/policy_search.py`) later in this notebook!
#
# The agent controls the quadcopter by setting the revolutions per second on each of its four rotors.  The provided agent in the `Basic_Agent` class below always selects a random action for each of the four rotors.  These four speeds are returned by the `act` method as a list of four floating-point numbers.
#
# For this project, the agent that you will implement in `agents/agent.py` will have a far more intelligent method for selecting actions!

# %%
import random

class Basic_Agent():
    def __init__(self, task):
        self.task = task
    
    def act(self):
        new_thrust = random.gauss(450., 25.)
        return [new_thrust + random.gauss(0., 1.) for x in range(4)]

# %% [markdown]
# Run the code cell below to have the agent select actions to control the quadcopter.
#
# Feel free to change the provided values of `runtime`, `init_pose`, `init_velocities`, and `init_angle_velocities` below to change the starting conditions of the quadcopter.
#
# The `labels` list below annotates statistics that are saved while running the simulation.  All of this information is saved in a text file `data.txt` and stored in the dictionary `results`.

# %%
# %load_ext autoreload
# %autoreload 2

import csv
import numpy as np
from task import Task

# %%
# Modify the values below to give the quadcopter a different starting position.
runtime = 5.                                     # time limit of the episode
init_pose = np.array([0., 0., 10., 0., 0., 0.])  # initial pose
init_velocities = np.array([0., 0., 0.])         # initial velocities
init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities
file_output = 'data.txt'                         # file name for saved results

# Setup
task = Task(init_pose, init_velocities, init_angle_velocities, runtime)
agent = Basic_Agent(task)
done = False
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

# Run the simulation, and save the results.
with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    while True:
        rotor_speeds = agent.act()
        _, _, done = task.step(rotor_speeds)
        to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
        for ii in range(len(labels)):
            results[labels[ii]].append(to_write[ii])
        writer.writerow(to_write)
        if done:
            break

# %% [markdown]
# Run the code cell below to visualize how the position of the quadcopter evolved during the simulation.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(results['time'], results['x'], label='x')
plt.plot(results['time'], results['y'], label='y')
plt.plot(results['time'], results['z'], label='z')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# The next code cell visualizes the velocity of the quadcopter.

# %%
plt.plot(results['time'], results['x_velocity'], label='x_hat')
plt.plot(results['time'], results['y_velocity'], label='y_hat')
plt.plot(results['time'], results['z_velocity'], label='z_hat')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Next, you can plot the Euler angles (the rotation of the quadcopter over the $x$-, $y$-, and $z$-axes),

# %%
plt.plot(results['time'], results['phi'], label='phi')
plt.plot(results['time'], results['theta'], label='theta')
plt.plot(results['time'], results['psi'], label='psi')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# before plotting the velocities (in radians per second) corresponding to each of the Euler angles.

# %%
plt.plot(results['time'], results['phi_velocity'], label='phi_velocity')
plt.plot(results['time'], results['theta_velocity'], label='theta_velocity')
plt.plot(results['time'], results['psi_velocity'], label='psi_velocity')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Finally, you can use the code cell below to print the agent's choice of actions.

# %%
plt.plot(results['time'], results['rotor_speed1'], label='Rotor 1 revolutions / second')
plt.plot(results['time'], results['rotor_speed2'], label='Rotor 2 revolutions / second')
plt.plot(results['time'], results['rotor_speed3'], label='Rotor 3 revolutions / second')
plt.plot(results['time'], results['rotor_speed4'], label='Rotor 4 revolutions / second')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# When specifying a task, you will derive the environment state from the simulator.  Run the code cell below to print the values of the following variables at the end of the simulation:
# - `task.sim.pose` (the position of the quadcopter in ($x,y,z$) dimensions and the Euler angles),
# - `task.sim.v` (the velocity of the quadcopter in ($x,y,z$) dimensions), and
# - `task.sim.angular_v` (radians/second for each of the three Euler angles).

# %%
# the pose, velocity, and angular velocity of the quadcopter at the end of the episode
print(task.sim.pose)
print(task.sim.v)
print(task.sim.angular_v)
# Out:
# [-22.12068315  19.63948152  19.50547682   1.18111855   0.60983968   0.        ]
# [-11.75514569  11.42053001  -5.10866748]
# [ 0.41295542  0.17700042  0.        ]

# %% [markdown]
# In the sample task in `task.py`, we use the 6-dimensional pose of the quadcopter to construct the state of the environment at each timestep.  However, when amending the task for your purposes, you are welcome to expand the size of the state vector by including the velocity information.  You can use any combination of the pose, velocity, and angular velocity - feel free to tinker here, and construct the state to suit your task.
#
# ## The Task
#
# A sample task has been provided for you in `task.py`.  Open this file in a new window now.
#
# The `__init__()` method is used to initialize several variables that are needed to specify the task.
# - The simulator is initialized as an instance of the `PhysicsSim` class (from `physics_sim.py`).
# - Inspired by the methodology in the original DDPG paper, we make use of action repeats.  For each timestep of the agent, we step the simulation `action_repeats` timesteps.  If you are not familiar with action repeats, please read the **Results** section in [the DDPG paper](https://arxiv.org/abs/1509.02971).
# - We set the number of elements in the state vector.  For the sample task, we only work with the 6-dimensional pose information.  To set the size of the state (`state_size`), we must take action repeats into account.
# - The environment will always have a 4-dimensional action space, with one entry for each rotor (`action_size=4`). You can set the minimum (`action_low`) and maximum (`action_high`) values of each entry here.
# - The sample task in this provided file is for the agent to reach a target position.  We specify that target position as a variable.
#
# The `reset()` method resets the simulator.  The agent should call this method every time the episode ends.  You can see an example of this in the code cell below.
#
# The `step()` method is perhaps the most important.  It accepts the agent's choice of action `rotor_speeds`, which is used to prepare the next state to pass on to the agent.  Then, the reward is computed from `get_reward()`.  The episode is considered done if the time limit has been exceeded, or the quadcopter has travelled outside of the bounds of the simulation.
#
# In the next section, you will learn how to test the performance of an agent on this task.

# %% [markdown]
# ## The Agent
#
# The sample agent given in `agents/policy_search.py` uses a very simplistic linear policy to directly compute the action vector as a dot product of the state vector and a matrix of weights. Then, it randomly perturbs the parameters by adding some Gaussian noise, to produce a different policy. Based on the average reward obtained in each episode (`score`), it keeps track of the best set of parameters found so far, how the score is changing, and accordingly tweaks a scaling factor to widen or tighten the noise.
#
# Run the code cell below to see how the agent performs on the sample task.

# %%
import sys
import pandas as pd
from agents.policy_search import PolicySearch_Agent
from task import Task

num_episodes = 100
target_pos = np.array([0., 0., 10.])
task = Task(target_pos=target_pos)
agent = PolicySearch_Agent(task) 

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        agent.step(reward, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
                i_episode, agent.score, agent.best_score, agent.noise_scale), end="")  # [debug]
            break
    sys.stdout.flush()
# Out:
# Episode =  100, score =  -0.783 (best =  -0.227), noise_scale = 3.255

# %% [markdown]
# This agent should perform very poorly on this task.  And that's where you come in!

# %% [markdown]
# ## Define the Task, Design the Agent, and Train Your Agent!
#
# Amend `task.py` to specify a task of your choosing.  If you're unsure what kind of task to specify, you may like to teach your quadcopter to takeoff, hover in place, land softly, or reach a target pose.
#
# After specifying your task, use the sample agent in `agents/policy_search.py` as a template to define your own agent in `agents/agent.py`.  You can borrow whatever you need from the sample agent, including ideas on how you might modularize your code (using helper methods like `act()`, `learn()`, `reset_episode()`, etc.).
#
# Note that it is **highly unlikely** that the first agent and task that you specify will learn well.  You will likely have to tweak various hyperparameters and the reward function for your task until you arrive at reasonably good behavior.
#
# As you develop your agent, it's important to keep an eye on how it's performing. Use the code above as inspiration to build in a mechanism to log/save the total rewards obtained in each episode to file.  If the episode rewards are gradually increasing, this is an indication that your agent is learning.

# %%
## TODO: Train your agent here.
import numpy as np
import sys
#from agents.ddpg.ddpg import DDPG
from mytask import MyTask
from agents.myagent import MyAgent

num_episodes = 5000
# Take off task
# Quadcopter stands still at the ground and has as target a height of 100 above the sarting point
init_pos = np.array([0., 0., 0., 0., 0., 0.])
target_pos = 100
task = MyTask(init_pose=init_pos, target_pos=target_pos,runtime=10.)
agent = MyAgent(task)
# save rewards for plotting
rewards = []
x=[]
y=[]
z=[]


for i_episode in range(1, num_episodes+1):
    episode_reward=0
    
    state = agent.reset_episode() # start a new episode
    
    while True:
        
        action = agent.act(state)
        next_state, reward, done = task.step(action)
        agent.step(action, reward, next_state, done)
        state = next_state
#         print(reward)
#         print(state)
        episode_reward+=reward
#         print("reward={}, position={}".format(agent.score,task.sim.pose[2]))
        if done:
            rewards.append(episode_reward)
            x.append(task.sim.pose[0])
            y.append(task.sim.pose[1])
            z.append(task.sim.pose[2])
            print("\r\nEpisode = {:4d}, episode_reward={}, z dim={},score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
                    i_episode,episode_reward,task.sim.pose[2], agent.score, agent.best_score, agent.noise_scale), end="") 
            break
    sys.stdout.flush()
# Out:
# Using TensorFlow backend.
# Episode =    1, episode_reward=-1985.0260416684819, z dim=0.0,score = -1985.026 (best = -1985.026), noise_scale = 0.1
# Episode =    2, episode_reward=-2983.8100812638845, z dim=0.0,score = -2983.810 (best = -1985.026), noise_scale = 0.1
# Episode =    3, episode_reward=-2999.1596688232053, z dim=0.0,score = -2999.160 (best = -1985.026), noise_scale = 0.1
# Episode =    4, episode_reward=-2984.890866168963, z dim=0.0,score = -2984.891 (best = -1985.026), noise_scale = 0.1
# Episode =    5, episode_reward=-1992.7471431482973, z dim=0.0,score = -1992.747 (best = -1985.026), noise_scale = 0.1
# Episode =    6, episode_reward=-1984.8952616895115, z dim=0.0,score = -1984.895 (best = -1984.895), noise_scale = 0.1
# Episode =    7, episode_reward=-1999.6288938527655, z dim=0.0,score = -1999.629 (best = -1984.895), noise_scale = 0.1
# Episode =    8, episode_reward=-1985.1261434082417, z dim=0.0,score = -1985.126 (best = -1984.895), noise_scale = 0.1
# Episode =    9, episode_reward=-2999.1516718599773, z dim=0.0,score = -2999.152 (best = -1984.895), noise_scale = 0.1
# Episode =   10, episode_reward=-999.2598240826696, z dim=0.0,score = -999.260 (best = -999.260), noise_scale = 0.1
# Episode =   11, episode_reward=-1979.044589036874, z dim=0.0,score = -1979.045 (best = -999.260), noise_scale = 0.1
# Episode =   12, episode_reward=-1999.7426902689838, z dim=0.0,score = -1999.743 (best = -999.260), noise_scale = 0.1
# Episode =   13, episode_reward=-1999.9272892673612, z dim=0.0,score = -1999.927 (best = -999.260), noise_scale = 0.1
# Episode =   14, episode_reward=-2999.9682161614537, z dim=0.0,score = -2999.968 (best = -999.260), noise_scale = 0.1
# Episode =   15, episode_reward=-2999.985537540959, z dim=0.0,score = -2999.986 (best = -999.260), noise_scale = 0.1
# Episode =   16, episode_reward=-999.9924299292065, z dim=0.0,score = -999.992 (best = -999.260), noise_scale = 0.1
# Episode =   17, episode_reward=-999.9958272603108, z dim=0.0,score = -999.996 (best = -999.260), noise_scale = 0.1
# Episode =   18, episode_reward=-1999.9971755999218, z dim=0.0,score = -1999.997 (best = -999.260), noise_scale = 0.1
# Episode =   19, episode_reward=-1999.9972711274681, z dim=0.0,score = -1999.997 (best = -999.260), noise_scale = 0.1
# Episode =   20, episode_reward=-1999.9974368703192, z dim=0.0,score = -1999.997 (best = -999.260), noise_scale = 0.1
# Episode =   21, episode_reward=-1999.9975839725485, z dim=0.0,score = -1999.998 (best = -999.260), noise_scale = 0.1
# Episode =   22, episode_reward=-1999.9977239308967, z dim=0.0,score = -1999.998 (best = -999.260), noise_scale = 0.1
# Episode =   23, episode_reward=-1999.9978996732611, z dim=0.0,score = -1999.998 (best = -999.260), noise_scale = 0.1
# Episode =   24, episode_reward=-1999.9980691457804, z dim=0.0,score = -1999.998 (best = -999.260), noise_scale = 0.1
# Episode =   25, episode_reward=-1999.998215696979, z dim=0.0,score = -1999.998 (best = -999.260), noise_scale = 0.1
# Episode =   26, episode_reward=-1999.998386264947, z dim=0.0,score = -1999.998 (best = -999.260), noise_scale = 0.1
# Episode =   27, episode_reward=-1999.9985569003654, z dim=0.0,score = -1999.999 (best = -999.260), noise_scale = 0.1
# Episode =   28, episode_reward=-1999.9987097352441, z dim=0.0,score = -1999.999 (best = -999.260), noise_scale = 0.1
# Episode =   29, episode_reward=-1999.9988804292263, z dim=0.0,score = -1999.999 (best = -999.260), noise_scale = 0.1
# Episode =   30, episode_reward=-1999.999054669744, z dim=0.0,score = -1999.999 (best = -999.260), noise_scale = 0.1
# Episode =   31, episode_reward=-1999.9992498652564, z dim=0.0,score = -1999.999 (best = -999.260), noise_scale = 0.1
# Episode =   32, episode_reward=-1999.9994054799704, z dim=0.0,score = -1999.999 (best = -999.260), noise_scale = 0.1
# Episode =   33, episode_reward=-1999.9995878672717, z dim=0.0,score = -2000.000 (best = -999.260), noise_scale = 0.1
# Episode =   34, episode_reward=-1999.9997672887669, z dim=0.0,score = -2000.000 (best = -999.260), noise_scale = 0.1
# Episode =   35, episode_reward=-1999.9999612109013, z dim=0.0,score = -2000.000 (best = -999.260), noise_scale = 0.1
# Episode =   36, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   37, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   38, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   39, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   40, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   41, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   42, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   43, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   44, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   45, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   46, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   47, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   48, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   49, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   50, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   51, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   52, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   53, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   54, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   55, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   56, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   57, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   58, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   59, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   60, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   61, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   62, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   63, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   64, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   65, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   66, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   67, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   68, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   69, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   70, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   71, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   72, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   73, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   74, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   75, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   76, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   77, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   78, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   79, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   80, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   81, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   82, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   83, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   84, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   85, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   86, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   87, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   88, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   89, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   90, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   91, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   92, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   93, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   94, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   95, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   96, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   97, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   98, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =   99, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  100, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  101, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  102, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  103, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  104, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  105, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  106, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  107, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  108, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  109, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  110, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  111, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  112, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  113, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  114, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  115, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  116, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  117, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  118, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  119, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  120, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  121, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  122, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  123, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  124, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  125, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  126, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  127, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  128, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  129, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  130, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  131, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  132, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  133, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  134, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  135, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  136, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  137, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  138, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  139, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  140, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  141, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  142, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  143, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  144, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  145, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  146, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  147, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  148, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  149, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  150, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  151, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  152, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  153, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  154, episode_reward=-3000, z dim=0.0,score = -3000.000 (best = -999.260), noise_scale = 0.1
# Episode =  155, episode_reward=-1999.9998364667088, z dim=0.0,score = -2000.000 (best = -999.260), noise_scale = 0.1
# Episode =  156, episode_reward=-1999.9993931383278, z dim=0.0,score = -1999.999 (best = -999.260), noise_scale = 0.1
# Episode =  157, episode_reward=-1999.9852630252828, z dim=0.0,score = -1999.985 (best = -999.260), noise_scale = 0.1
# Episode =  158, episode_reward=-1999.998322179168, z dim=0.0,score = -1999.998 (best = -999.260), noise_scale = 0.1
# Episode =  159, episode_reward=-1999.9980466885881, z dim=0.0,score = -1999.998 (best = -999.260), noise_scale = 0.1
# Episode =  160, episode_reward=-1999.9978152440585, z dim=0.0,score = -1999.998 (best = -999.260), noise_scale = 0.1
# Episode =  161, episode_reward=-1999.9975936347807, z dim=0.0,score = -1999.998 (best = -999.260), noise_scale = 0.1
# Episode =  162, episode_reward=-999.9871793192337, z dim=0.0,score = -999.987 (best = -999.260), noise_scale = 0.1
# Episode =  163, episode_reward=-999.9957348953792, z dim=0.0,score = -999.996 (best = -999.260), noise_scale = 0.1
# Episode =  164, episode_reward=-1999.9970324828403, z dim=0.0,score = -1999.997 (best = -999.260), noise_scale = 0.1
# Episode =  165, episode_reward=-999.9945281714997, z dim=0.0,score = -999.995 (best = -999.260), noise_scale = 0.1
# Episode =  166, episode_reward=-1999.9967401390495, z dim=0.0,score = -1999.997 (best = -999.260), noise_scale = 0.1
# Episode =  167, episode_reward=-1999.9966071979961, z dim=0.0,score = -1999.997 (best = -999.260), noise_scale = 0.1
# Episode =  168, episode_reward=-999.9830653329144, z dim=0.0,score = -999.983 (best = -999.260), noise_scale = 0.1
# Episode =  169, episode_reward=-1999.9963260546035, z dim=0.0,score = -1999.996 (best = -999.260), noise_scale = 0.1
# Episode =  170, episode_reward=-1999.9962009325711, z dim=0.0,score = -1999.996 (best = -999.260), noise_scale = 0.1
# Episode =  171, episode_reward=-1999.9960862035489, z dim=0.0,score = -1999.996 (best = -999.260), noise_scale = 0.1
# Episode =  172, episode_reward=-1999.9959318350498, z dim=0.0,score = -1999.996 (best = -999.260), noise_scale = 0.1
# Episode =  173, episode_reward=-1999.995780882799, z dim=0.0,score = -1999.996 (best = -999.260), noise_scale = 0.1
# Episode =  174, episode_reward=-999.9792593586017, z dim=0.0,score = -999.979 (best = -999.260), noise_scale = 0.1
# Episode =  175, episode_reward=-1999.9954036598276, z dim=0.0,score = -1999.995 (best = -999.260), noise_scale = 0.1
# Episode =  176, episode_reward=-999.9795279581464, z dim=0.0,score = -999.980 (best = -999.260), noise_scale = 0.1
# Episode =  177, episode_reward=-999.977924225956, z dim=0.0,score = -999.978 (best = -999.260), noise_scale = 0.1
# Episode =  178, episode_reward=-1999.9944291759298, z dim=0.0,score = -1999.994 (best = -999.260), noise_scale = 0.1
# Episode =  179, episode_reward=-2999.950362201153, z dim=0.0,score = -2999.950 (best = -999.260), noise_scale = 0.1
# Episode =  180, episode_reward=-1999.9213033552105, z dim=0.0,score = -1999.921 (best = -999.260), noise_scale = 0.1
# Episode =  181, episode_reward=-1999.9905107818163, z dim=0.0,score = -1999.991 (best = -999.260), noise_scale = 0.1
# Episode =  182, episode_reward=-2999.9671975142446, z dim=0.0,score = -2999.967 (best = -999.260), noise_scale = 0.1
# Episode =  183, episode_reward=-1999.986018788109, z dim=0.0,score = -1999.986 (best = -999.260), noise_scale = 0.1
# Episode =  184, episode_reward=-999.9763439603805, z dim=0.0,score = -999.976 (best = -999.260), noise_scale = 0.1
# Episode =  185, episode_reward=-1960.575600800446, z dim=0.0,score = -1960.576 (best = -999.260), noise_scale = 0.1
# Episode =  186, episode_reward=-999.9503509837341, z dim=0.0,score = -999.950 (best = -999.260), noise_scale = 0.1
# Episode =  187, episode_reward=-999.9273886775468, z dim=0.0,score = -999.927 (best = -999.260), noise_scale = 0.1
# Episode =  188, episode_reward=-2999.8832724987847, z dim=0.0,score = -2999.883 (best = -999.260), noise_scale = 0.1
# Episode =  189, episode_reward=-1999.6699772638233, z dim=0.0,score = -1999.670 (best = -999.260), noise_scale = 0.1
# Episode =  190, episode_reward=-1998.8948613524828, z dim=0.0,score = -1998.895 (best = -999.260), noise_scale = 0.1
# Episode =  191, episode_reward=676.8185114570804, z dim=0.0,score = 676.819 (best = 676.819), noise_scale = 0.1
# Episode =  192, episode_reward=265485.19293682504, z dim=75.87308744459526,score = 265485.193 (best = 265485.193), noise_scale = 0.1
# Episode =  193, episode_reward=-999.6869147580685, z dim=0.01327913999411506,score = -999.687 (best = 265485.193), noise_scale = 0.1
# Episode =  194, episode_reward=-999.8838955278949, z dim=0.0,score = -999.884 (best = 265485.193), noise_scale = 0.1
# Episode =  195, episode_reward=-999.0034558105933, z dim=0.0,score = -999.003 (best = 265485.193), noise_scale = 0.1
# Episode =  196, episode_reward=-1999.7175281620925, z dim=0.0,score = -1999.718 (best = 265485.193), noise_scale = 0.1
# Episode =  197, episode_reward=-1981.3004420513134, z dim=0.0,score = -1981.300 (best = 265485.193), noise_scale = 0.1
# Episode =  198, episode_reward=-2993.6487230591165, z dim=0.0,score = -2993.649 (best = 265485.193), noise_scale = 0.1
# Episode =  199, episode_reward=-1994.6531602324962, z dim=0.0,score = -1994.653 (best = 265485.193), noise_scale = 0.1
# Episode =  200, episode_reward=-2993.4340947489136, z dim=0.0,score = -2993.434 (best = 265485.193), noise_scale = 0.1
# Episode =  201, episode_reward=-999.867555495282, z dim=0.0,score = -999.868 (best = 265485.193), noise_scale = 0.1
# Episode =  202, episode_reward=-2999.840857203141, z dim=0.0,score = -2999.841 (best = 265485.193), noise_scale = 0.1
# Episode =  203, episode_reward=-2990.485174650878, z dim=0.0,score = -2990.485 (best = 265485.193), noise_scale = 0.1
# Episode =  204, episode_reward=-996.033142375047, z dim=0.0,score = -996.033 (best = 265485.193), noise_scale = 0.1
# Episode =  205, episode_reward=-999.4572628868663, z dim=0.0,score = -999.457 (best = 265485.193), noise_scale = 0.1
# Episode =  206, episode_reward=-999.5863139416929, z dim=0.0,score = -999.586 (best = 265485.193), noise_scale = 0.1
# Episode =  207, episode_reward=-999.5823361017646, z dim=0.0,score = -999.582 (best = 265485.193), noise_scale = 0.1
# Episode =  208, episode_reward=-999.8786437914457, z dim=0.0,score = -999.879 (best = 265485.193), noise_scale = 0.1
# Episode =  209, episode_reward=-999.877615844433, z dim=0.0,score = -999.878 (best = 265485.193), noise_scale = 0.1
# Episode =  210, episode_reward=-999.8784473780886, z dim=0.0,score = -999.878 (best = 265485.193), noise_scale = 0.1
# Episode =  211, episode_reward=-999.8688022306119, z dim=0.0,score = -999.869 (best = 265485.193), noise_scale = 0.1
# Episode =  212, episode_reward=-999.8599392611402, z dim=0.0,score = -999.860 (best = 265485.193), noise_scale = 0.1
# Episode =  213, episode_reward=-2999.743220852225, z dim=0.0,score = -2999.743 (best = 265485.193), noise_scale = 0.1
# Episode =  214, episode_reward=-2999.8110747805435, z dim=0.0,score = -2999.811 (best = 265485.193), noise_scale = 0.1
# Episode =  215, episode_reward=-2998.979962926612, z dim=0.0,score = -2998.980 (best = 265485.193), noise_scale = 0.1
# Episode =  216, episode_reward=-1953.8007920722575, z dim=0.0,score = -1953.801 (best = 265485.193), noise_scale = 0.1
# Episode =  217, episode_reward=-1989.9341832032414, z dim=0.0,score = -1989.934 (best = 265485.193), noise_scale = 0.1
# Episode =  218, episode_reward=-1994.321282033524, z dim=0.0,score = -1994.321 (best = 265485.193), noise_scale = 0.1
# Episode =  219, episode_reward=-1987.2815173809468, z dim=0.0,score = -1987.282 (best = 265485.193), noise_scale = 0.1
# Episode =  220, episode_reward=-2987.223354775851, z dim=0.0,score = -2987.223 (best = 265485.193), noise_scale = 0.1
# Episode =  221, episode_reward=-2999.1914556525335, z dim=0.0,score = -2999.191 (best = 265485.193), noise_scale = 0.1
# Episode =  222, episode_reward=-2999.217667448728, z dim=0.0,score = -2999.218 (best = 265485.193), noise_scale = 0.1
# Episode =  223, episode_reward=-2999.3725996730186, z dim=0.0,score = -2999.373 (best = 265485.193), noise_scale = 0.1
# Episode =  224, episode_reward=-2999.1670137136234, z dim=0.0,score = -2999.167 (best = 265485.193), noise_scale = 0.1
# Episode =  225, episode_reward=-999.2192754750914, z dim=0.0,score = -999.219 (best = 265485.193), noise_scale = 0.1
# Episode =  226, episode_reward=-2999.3817402532595, z dim=0.0,score = -2999.382 (best = 265485.193), noise_scale = 0.1
# Episode =  227, episode_reward=-2999.357736523615, z dim=0.0,score = -2999.358 (best = 265485.193), noise_scale = 0.1
# Episode =  228, episode_reward=-999.2644648751804, z dim=0.0,score = -999.264 (best = 265485.193), noise_scale = 0.1
# Episode =  229, episode_reward=-999.5195071939523, z dim=0.0,score = -999.520 (best = 265485.193), noise_scale = 0.1
# Episode =  230, episode_reward=-2996.117896516781, z dim=0.0,score = -2996.118 (best = 265485.193), noise_scale = 0.1
# Episode =  231, episode_reward=-999.4499986960143, z dim=0.0,score = -999.450 (best = 265485.193), noise_scale = 0.1
# Episode =  232, episode_reward=-999.5373880767092, z dim=0.0,score = -999.537 (best = 265485.193), noise_scale = 0.1
# Episode =  233, episode_reward=-999.4559803964667, z dim=0.0,score = -999.456 (best = 265485.193), noise_scale = 0.1
# Episode =  234, episode_reward=-999.5131370421379, z dim=0.0,score = -999.513 (best = 265485.193), noise_scale = 0.1
# Episode =  235, episode_reward=-999.4432513286799, z dim=0.0,score = -999.443 (best = 265485.193), noise_scale = 0.1
# Episode =  236, episode_reward=-999.6846559041643, z dim=0.003999831838387686,score = -999.685 (best = 265485.193), noise_scale = 0.1
# Episode =  237, episode_reward=-999.5298596619991, z dim=0.0,score = -999.530 (best = 265485.193), noise_scale = 0.1
# Episode =  238, episode_reward=-1999.5403770070595, z dim=0.0,score = -1999.540 (best = 265485.193), noise_scale = 0.1
# Episode =  239, episode_reward=-999.4169181729079, z dim=0.0,score = -999.417 (best = 265485.193), noise_scale = 0.1
# Episode =  240, episode_reward=-999.5516056932368, z dim=0.0,score = -999.552 (best = 265485.193), noise_scale = 0.1
# Episode =  241, episode_reward=-999.7015210486741, z dim=0.003459796873812292,score = -999.702 (best = 265485.193), noise_scale = 0.1
# Episode =  242, episode_reward=-1999.6307855283567, z dim=0.0,score = -1999.631 (best = 265485.193), noise_scale = 0.1
# Episode =  243, episode_reward=-999.6958100920854, z dim=0.0016760588813628475,score = -999.696 (best = 265485.193), noise_scale = 0.1
# Episode =  244, episode_reward=-2999.5991239846617, z dim=0.0,score = -2999.599 (best = 265485.193), noise_scale = 0.1
# Episode =  245, episode_reward=-1999.5742504022446, z dim=0.0,score = -1999.574 (best = 265485.193), noise_scale = 0.1
# Episode =  246, episode_reward=-999.5084829520755, z dim=0.0,score = -999.508 (best = 265485.193), noise_scale = 0.1
# Episode =  247, episode_reward=-999.7140807739163, z dim=0.004340234849259683,score = -999.714 (best = 265485.193), noise_scale = 0.1
# Episode =  248, episode_reward=-1999.8090327415357, z dim=0.0,score = -1999.809 (best = 265485.193), noise_scale = 0.1
# Episode =  249, episode_reward=-999.7528860730239, z dim=0.004842910950131606,score = -999.753 (best = 265485.193), noise_scale = 0.1
# Episode =  250, episode_reward=-1999.7119464737523, z dim=0.0,score = -1999.712 (best = 265485.193), noise_scale = 0.1
# Episode =  251, episode_reward=-999.773712089078, z dim=0.0020361428774672724,score = -999.774 (best = 265485.193), noise_scale = 0.1
# Episode =  252, episode_reward=-1999.718765096771, z dim=0.0,score = -1999.719 (best = 265485.193), noise_scale = 0.1
# Episode =  253, episode_reward=-999.7659069397878, z dim=0.00617140435884189,score = -999.766 (best = 265485.193), noise_scale = 0.1
# Episode =  254, episode_reward=-1999.7576277362264, z dim=0.0,score = -1999.758 (best = 265485.193), noise_scale = 0.1
# Episode =  255, episode_reward=-1999.8547299036086, z dim=0.00032286783599830325,score = -1999.855 (best = 265485.193), noise_scale = 0.1
# Episode =  256, episode_reward=-999.7090170728694, z dim=0.004098254885280464,score = -999.709 (best = 265485.193), noise_scale = 0.1
# Episode =  257, episode_reward=-1999.8166008407318, z dim=0.003155009999946594,score = -1999.817 (best = 265485.193), noise_scale = 0.1
# Episode =  258, episode_reward=-999.766830913018, z dim=0.005720107604814469,score = -999.767 (best = 265485.193), noise_scale = 0.1
# Episode =  259, episode_reward=-999.7524547728722, z dim=0.005711800141806517,score = -999.752 (best = 265485.193), noise_scale = 0.1
# Episode =  260, episode_reward=-999.7545898486935, z dim=0.005409379150343867,score = -999.755 (best = 265485.193), noise_scale = 0.1
# Episode =  261, episode_reward=-999.7481396229608, z dim=0.0056975819484977475,score = -999.748 (best = 265485.193), noise_scale = 0.1
# Episode =  262, episode_reward=-1999.7350600794105, z dim=0.0,score = -1999.735 (best = 265485.193), noise_scale = 0.1
# Episode =  263, episode_reward=-1999.8162631010648, z dim=0.005366819065482583,score = -1999.816 (best = 265485.193), noise_scale = 0.1
# Episode =  264, episode_reward=-999.8755852994173, z dim=0.0,score = -999.876 (best = 265485.193), noise_scale = 0.1
# Episode =  265, episode_reward=-999.8793623771614, z dim=0.0,score = -999.879 (best = 265485.193), noise_scale = 0.1
# Episode =  266, episode_reward=-1999.8187873817074, z dim=0.0036094889879137193,score = -1999.819 (best = 265485.193), noise_scale = 0.1
# Episode =  267, episode_reward=-2999.8697018912835, z dim=0.0,score = -2999.870 (best = 265485.193), noise_scale = 0.1
# Episode =  268, episode_reward=-1999.7371977154921, z dim=0.0,score = -1999.737 (best = 265485.193), noise_scale = 0.1
# Episode =  269, episode_reward=-999.8794190235418, z dim=0.0,score = -999.879 (best = 265485.193), noise_scale = 0.1
# Episode =  270, episode_reward=-999.8795431021575, z dim=0.0,score = -999.880 (best = 265485.193), noise_scale = 0.1
# Episode =  271, episode_reward=-2999.8739397465706, z dim=0.0,score = -2999.874 (best = 265485.193), noise_scale = 0.1
# Episode =  272, episode_reward=-1999.7894383272474, z dim=0.007572798951946205,score = -1999.789 (best = 265485.193), noise_scale = 0.1
# Episode =  273, episode_reward=-1999.8346439570719, z dim=0.00374427477669441,score = -1999.835 (best = 265485.193), noise_scale = 0.1
# Episode =  274, episode_reward=-1999.6153075849386, z dim=0.0,score = -1999.615 (best = 265485.193), noise_scale = 0.1
# Episode =  275, episode_reward=-1999.7865103251252, z dim=0.005859474794884319,score = -1999.787 (best = 265485.193), noise_scale = 0.1
# Episode =  276, episode_reward=-999.8752060981082, z dim=0.0,score = -999.875 (best = 265485.193), noise_scale = 0.1
# Episode =  277, episode_reward=-999.8797501740266, z dim=0.0,score = -999.880 (best = 265485.193), noise_scale = 0.1
# Episode =  278, episode_reward=-1999.798240821011, z dim=0.007249542989531378,score = -1999.798 (best = 265485.193), noise_scale = 0.1
# Episode =  279, episode_reward=-999.8799113744759, z dim=0.0,score = -999.880 (best = 265485.193), noise_scale = 0.1
# Episode =  280, episode_reward=-999.8800788455388, z dim=0.0,score = -999.880 (best = 265485.193), noise_scale = 0.1
# Episode =  281, episode_reward=-999.8774525219266, z dim=0.0,score = -999.877 (best = 265485.193), noise_scale = 0.1
# Episode =  282, episode_reward=-999.8799297755799, z dim=0.0,score = -999.880 (best = 265485.193), noise_scale = 0.1
# Episode =  283, episode_reward=-2999.835434347463, z dim=0.0,score = -2999.835 (best = 265485.193), noise_scale = 0.1
# Episode =  284, episode_reward=-1999.8254424918528, z dim=0.0,score = -1999.825 (best = 265485.193), noise_scale = 0.1
# Episode =  285, episode_reward=-999.8643166989625, z dim=0.0,score = -999.864 (best = 265485.193), noise_scale = 0.1
# Episode =  286, episode_reward=-999.877853168915, z dim=0.0,score = -999.878 (best = 265485.193), noise_scale = 0.1
# Episode =  287, episode_reward=-999.876840136855, z dim=0.0,score = -999.877 (best = 265485.193), noise_scale = 0.1
# Episode =  288, episode_reward=-999.8733148584997, z dim=0.0,score = -999.873 (best = 265485.193), noise_scale = 0.1
# Episode =  289, episode_reward=-2999.8464453783854, z dim=0.0,score = -2999.846 (best = 265485.193), noise_scale = 0.1
# Episode =  290, episode_reward=-2999.0949592436573, z dim=0.0,score = -2999.095 (best = 265485.193), noise_scale = 0.1
# Episode =  291, episode_reward=-2997.7823020464816, z dim=0.0,score = -2997.782 (best = 265485.193), noise_scale = 0.1
# Episode =  292, episode_reward=-992.7048313768859, z dim=0.0,score = -992.705 (best = 265485.193), noise_scale = 0.1
# Episode =  293, episode_reward=-1999.4595926417092, z dim=0.0,score = -1999.460 (best = 265485.193), noise_scale = 0.1
# Episode =  294, episode_reward=-1999.8558559316425, z dim=0.0,score = -1999.856 (best = 265485.193), noise_scale = 0.1
# Episode =  295, episode_reward=-999.4513409345234, z dim=0.0,score = -999.451 (best = 265485.193), noise_scale = 0.1
# Episode =  296, episode_reward=-999.940275547322, z dim=0.0,score = -999.940 (best = 265485.193), noise_scale = 0.1
# Episode =  297, episode_reward=-999.7643111627641, z dim=0.0,score = -999.764 (best = 265485.193), noise_scale = 0.1
# Episode =  298, episode_reward=-999.929788634369, z dim=0.0,score = -999.930 (best = 265485.193), noise_scale = 0.1
# Episode =  299, episode_reward=-1999.2393433091343, z dim=0.0,score = -1999.239 (best = 265485.193), noise_scale = 0.1
# Episode =  300, episode_reward=-1999.8198218080106, z dim=0.0,score = -1999.820 (best = 265485.193), noise_scale = 0.1
# Episode =  301, episode_reward=-1999.7824466582108, z dim=0.0,score = -1999.782 (best = 265485.193), noise_scale = 0.1
# Episode =  302, episode_reward=-999.9167186299538, z dim=0.0,score = -999.917 (best = 265485.193), noise_scale = 0.1
# Episode =  303, episode_reward=-1999.7890718508042, z dim=0.0,score = -1999.789 (best = 265485.193), noise_scale = 0.1
# Episode =  304, episode_reward=-1999.799322543984, z dim=0.0,score = -1999.799 (best = 265485.193), noise_scale = 0.1
# Episode =  305, episode_reward=-1999.8136788186773, z dim=0.0,score = -1999.814 (best = 265485.193), noise_scale = 0.1
# Episode =  306, episode_reward=-2999.822117751719, z dim=0.0,score = -2999.822 (best = 265485.193), noise_scale = 0.1
# Episode =  307, episode_reward=-2999.819760697953, z dim=0.0,score = -2999.820 (best = 265485.193), noise_scale = 0.1
# Episode =  308, episode_reward=-2999.8158836104267, z dim=0.0,score = -2999.816 (best = 265485.193), noise_scale = 0.1
# Episode =  309, episode_reward=-2999.82977429888, z dim=0.0,score = -2999.830 (best = 265485.193), noise_scale = 0.1
# Episode =  310, episode_reward=-2999.82985390179, z dim=0.0,score = -2999.830 (best = 265485.193), noise_scale = 0.1
# Episode =  311, episode_reward=-1999.7139489029091, z dim=0.0,score = -1999.714 (best = 265485.193), noise_scale = 0.1
# Episode =  312, episode_reward=-1999.8393901596182, z dim=0.0,score = -1999.839 (best = 265485.193), noise_scale = 0.1
# Episode =  313, episode_reward=-1999.6898804453772, z dim=0.0,score = -1999.690 (best = 265485.193), noise_scale = 0.1
# Episode =  314, episode_reward=-1999.5054563287756, z dim=0.0,score = -1999.505 (best = 265485.193), noise_scale = 0.1
# Episode =  315, episode_reward=-1999.529253018079, z dim=0.0,score = -1999.529 (best = 265485.193), noise_scale = 0.1
# Episode =  316, episode_reward=-1995.4559335883653, z dim=0.0,score = -1995.456 (best = 265485.193), noise_scale = 0.1
# Episode =  317, episode_reward=-1998.7137609814408, z dim=0.0,score = -1998.714 (best = 265485.193), noise_scale = 0.1
# Episode =  318, episode_reward=-999.0375480487279, z dim=0.0,score = -999.038 (best = 265485.193), noise_scale = 0.1
# Episode =  319, episode_reward=-1999.3215484768193, z dim=0.0,score = -1999.322 (best = 265485.193), noise_scale = 0.1
# Episode =  320, episode_reward=-2996.326981483579, z dim=0.0,score = -2996.327 (best = 265485.193), noise_scale = 0.1
# Episode =  321, episode_reward=-997.3149921139842, z dim=0.0,score = -997.315 (best = 265485.193), noise_scale = 0.1
# Episode =  322, episode_reward=-1999.6822015423613, z dim=0.0,score = -1999.682 (best = 265485.193), noise_scale = 0.1
# Episode =  323, episode_reward=-2997.9783065422175, z dim=0.0,score = -2997.978 (best = 265485.193), noise_scale = 0.1
# Episode =  324, episode_reward=-1993.4628875172575, z dim=0.0,score = -1993.463 (best = 265485.193), noise_scale = 0.1
# Episode =  325, episode_reward=-2996.252909974162, z dim=0.0,score = -2996.253 (best = 265485.193), noise_scale = 0.1
# Episode =  326, episode_reward=-2996.190243834608, z dim=0.0,score = -2996.190 (best = 265485.193), noise_scale = 0.1
# Episode =  327, episode_reward=-999.6292031856618, z dim=0.0,score = -999.629 (best = 265485.193), noise_scale = 0.1
# Episode =  328, episode_reward=-1997.7627453630403, z dim=0.0,score = -1997.763 (best = 265485.193), noise_scale = 0.1
# Episode =  329, episode_reward=-2991.4117645818687, z dim=0.0,score = -2991.412 (best = 265485.193), noise_scale = 0.1
# Episode =  330, episode_reward=-993.3426455083085, z dim=0.0,score = -993.343 (best = 265485.193), noise_scale = 0.1
# Episode =  331, episode_reward=-997.0359557519741, z dim=0.0,score = -997.036 (best = 265485.193), noise_scale = 0.1
# Episode =  332, episode_reward=-995.505101212018, z dim=0.0,score = -995.505 (best = 265485.193), noise_scale = 0.1
# Episode =  333, episode_reward=-2994.339852956944, z dim=0.0,score = -2994.340 (best = 265485.193), noise_scale = 0.1
# Episode =  334, episode_reward=-999.0763455828388, z dim=0.0,score = -999.076 (best = 265485.193), noise_scale = 0.1
# Episode =  335, episode_reward=-999.0697016713372, z dim=0.0,score = -999.070 (best = 265485.193), noise_scale = 0.1
# Episode =  336, episode_reward=-1999.694969015427, z dim=0.0,score = -1999.695 (best = 265485.193), noise_scale = 0.1
# Episode =  337, episode_reward=-1999.3713220012864, z dim=0.0,score = -1999.371 (best = 265485.193), noise_scale = 0.1
# Episode =  338, episode_reward=-1998.947341975406, z dim=0.0,score = -1998.947 (best = 265485.193), noise_scale = 0.1
# Episode =  339, episode_reward=-999.5042933158669, z dim=0.0,score = -999.504 (best = 265485.193), noise_scale = 0.1
# Episode =  340, episode_reward=-2998.061518869504, z dim=0.0,score = -2998.062 (best = 265485.193), noise_scale = 0.1
# Episode =  341, episode_reward=-2998.027725527905, z dim=0.0,score = -2998.028 (best = 265485.193), noise_scale = 0.1
# Episode =  342, episode_reward=-2999.400498281529, z dim=0.0,score = -2999.400 (best = 265485.193), noise_scale = 0.1
# Episode =  343, episode_reward=-1999.2598573779942, z dim=0.0,score = -1999.260 (best = 265485.193), noise_scale = 0.1
# Episode =  344, episode_reward=-997.2812199397524, z dim=0.0,score = -997.281 (best = 265485.193), noise_scale = 0.1
# Episode =  345, episode_reward=-994.0520864845978, z dim=0.0,score = -994.052 (best = 265485.193), noise_scale = 0.1
# Episode =  346, episode_reward=-2999.1323743211356, z dim=0.0,score = -2999.132 (best = 265485.193), noise_scale = 0.1
# Episode =  347, episode_reward=-1997.0717773354513, z dim=0.0,score = -1997.072 (best = 265485.193), noise_scale = 0.1
# Episode =  348, episode_reward=-1996.6787561082888, z dim=0.0,score = -1996.679 (best = 265485.193), noise_scale = 0.1
# Episode =  349, episode_reward=-998.65761346182, z dim=0.0,score = -998.658 (best = 265485.193), noise_scale = 0.1
# Episode =  350, episode_reward=-2999.3399930368705, z dim=0.0,score = -2999.340 (best = 265485.193), noise_scale = 0.1
# Episode =  351, episode_reward=-998.5107902804409, z dim=0.0,score = -998.511 (best = 265485.193), noise_scale = 0.1
# Episode =  352, episode_reward=-2999.2993617947614, z dim=0.0,score = -2999.299 (best = 265485.193), noise_scale = 0.1
# Episode =  353, episode_reward=-1998.1965769345275, z dim=0.0,score = -1998.197 (best = 265485.193), noise_scale = 0.1
# Episode =  354, episode_reward=-1998.3294355931616, z dim=0.0,score = -1998.329 (best = 265485.193), noise_scale = 0.1
# Episode =  355, episode_reward=-2999.0373529107883, z dim=0.0,score = -2999.037 (best = 265485.193), noise_scale = 0.1
# Episode =  356, episode_reward=-2999.0451321035493, z dim=0.0,score = -2999.045 (best = 265485.193), noise_scale = 0.1
# Episode =  357, episode_reward=-998.3362526232277, z dim=0.0,score = -998.336 (best = 265485.193), noise_scale = 0.1
# Episode =  358, episode_reward=-2999.3164313312363, z dim=0.0,score = -2999.316 (best = 265485.193), noise_scale = 0.1
# Episode =  359, episode_reward=-998.3858088632618, z dim=0.0,score = -998.386 (best = 265485.193), noise_scale = 0.1
# Episode =  360, episode_reward=-996.6904281740906, z dim=0.0,score = -996.690 (best = 265485.193), noise_scale = 0.1
# Episode =  361, episode_reward=-2992.1582830261204, z dim=0.0,score = -2992.158 (best = 265485.193), noise_scale = 0.1
# Episode =  362, episode_reward=-1999.3815015967903, z dim=0.0,score = -1999.382 (best = 265485.193), noise_scale = 0.1
# Episode =  363, episode_reward=-2999.3665281378226, z dim=0.0,score = -2999.367 (best = 265485.193), noise_scale = 0.1
# Episode =  364, episode_reward=-998.480342428012, z dim=0.0,score = -998.480 (best = 265485.193), noise_scale = 0.1
# Episode =  365, episode_reward=-1997.4510885027694, z dim=0.0,score = -1997.451 (best = 265485.193), noise_scale = 0.1
# Episode =  366, episode_reward=-2998.6741784638316, z dim=0.0,score = -2998.674 (best = 265485.193), noise_scale = 0.1
# Episode =  367, episode_reward=-998.9983038434692, z dim=0.0,score = -998.998 (best = 265485.193), noise_scale = 0.1
# Episode =  368, episode_reward=-998.3587432933408, z dim=0.0,score = -998.359 (best = 265485.193), noise_scale = 0.1
# Episode =  369, episode_reward=-1998.9908518792743, z dim=0.0,score = -1998.991 (best = 265485.193), noise_scale = 0.1
# Episode =  370, episode_reward=-1998.918833389503, z dim=0.0,score = -1998.919 (best = 265485.193), noise_scale = 0.1
# Episode =  371, episode_reward=-999.4651432304597, z dim=0.0,score = -999.465 (best = 265485.193), noise_scale = 0.1
# Episode =  372, episode_reward=-1998.8917339489344, z dim=0.0,score = -1998.892 (best = 265485.193), noise_scale = 0.1
# Episode =  373, episode_reward=-1999.0314333816796, z dim=0.0,score = -1999.031 (best = 265485.193), noise_scale = 0.1
# Episode =  374, episode_reward=-1999.754969992045, z dim=0.0,score = -1999.755 (best = 265485.193), noise_scale = 0.1
# Episode =  375, episode_reward=-1998.9652467123765, z dim=0.0,score = -1998.965 (best = 265485.193), noise_scale = 0.1
# Episode =  376, episode_reward=-998.687800981665, z dim=0.0,score = -998.688 (best = 265485.193), noise_scale = 0.1
# Episode =  377, episode_reward=-998.6239549098472, z dim=0.0,score = -998.624 (best = 265485.193), noise_scale = 0.1
# Episode =  378, episode_reward=-2998.8633145000513, z dim=0.0,score = -2998.863 (best = 265485.193), noise_scale = 0.1
# Episode =  379, episode_reward=-1999.6415029605228, z dim=0.0,score = -1999.642 (best = 265485.193), noise_scale = 0.1
# Episode =  380, episode_reward=-2999.2597405946753, z dim=0.0,score = -2999.260 (best = 265485.193), noise_scale = 0.1
# Episode =  381, episode_reward=-1999.6746059108496, z dim=0.0,score = -1999.675 (best = 265485.193), noise_scale = 0.1
# Episode =  382, episode_reward=-2999.542663353355, z dim=0.0,score = -2999.543 (best = 265485.193), noise_scale = 0.1
# Episode =  383, episode_reward=-1997.5089360504148, z dim=0.0,score = -1997.509 (best = 265485.193), noise_scale = 0.1
# Episode =  384, episode_reward=-2999.1496333876967, z dim=0.0,score = -2999.150 (best = 265485.193), noise_scale = 0.1
# Episode =  385, episode_reward=-999.6686845111258, z dim=0.0,score = -999.669 (best = 265485.193), noise_scale = 0.1
# Episode =  386, episode_reward=-1997.7189347162819, z dim=0.0,score = -1997.719 (best = 265485.193), noise_scale = 0.1
# Episode =  387, episode_reward=-1996.1951846749646, z dim=0.0,score = -1996.195 (best = 265485.193), noise_scale = 0.1
# Episode =  388, episode_reward=-999.5365782729552, z dim=0.0,score = -999.537 (best = 265485.193), noise_scale = 0.1
# Episode =  389, episode_reward=-2996.7066240478666, z dim=0.0,score = -2996.707 (best = 265485.193), noise_scale = 0.1
# Episode =  390, episode_reward=-1996.2278660439702, z dim=0.0,score = -1996.228 (best = 265485.193), noise_scale = 0.1
# Episode =  391, episode_reward=-1996.1211510542853, z dim=0.0,score = -1996.121 (best = 265485.193), noise_scale = 0.1
# Episode =  392, episode_reward=-1998.8087095037567, z dim=0.0,score = -1998.809 (best = 265485.193), noise_scale = 0.1
# Episode =  393, episode_reward=-2998.5651555464415, z dim=0.0,score = -2998.565 (best = 265485.193), noise_scale = 0.1
# Episode =  394, episode_reward=-2998.332707885081, z dim=0.0,score = -2998.333 (best = 265485.193), noise_scale = 0.1
# Episode =  395, episode_reward=-999.6556631481103, z dim=0.0,score = -999.656 (best = 265485.193), noise_scale = 0.1
# Episode =  396, episode_reward=-2999.361697858136, z dim=0.0,score = -2999.362 (best = 265485.193), noise_scale = 0.1
# Episode =  397, episode_reward=-998.7014162137335, z dim=0.0,score = -998.701 (best = 265485.193), noise_scale = 0.1
# Episode =  398, episode_reward=-998.6102037261645, z dim=0.0,score = -998.610 (best = 265485.193), noise_scale = 0.1
# Episode =  399, episode_reward=-1999.7982615933347, z dim=0.0,score = -1999.798 (best = 265485.193), noise_scale = 0.1
# Episode =  400, episode_reward=-999.6395816403937, z dim=0.0,score = -999.640 (best = 265485.193), noise_scale = 0.1
# Episode =  401, episode_reward=-1998.9916904836812, z dim=0.0,score = -1998.992 (best = 265485.193), noise_scale = 0.1
# Episode =  402, episode_reward=-2996.236996233957, z dim=0.0,score = -2996.237 (best = 265485.193), noise_scale = 0.1
# Episode =  403, episode_reward=-2999.876563646909, z dim=0.0,score = -2999.877 (best = 265485.193), noise_scale = 0.1
# Episode =  404, episode_reward=-2998.1462535263395, z dim=0.0,score = -2998.146 (best = 265485.193), noise_scale = 0.1
# Episode =  405, episode_reward=-2998.5977013482407, z dim=0.0,score = -2998.598 (best = 265485.193), noise_scale = 0.1
# Episode =  406, episode_reward=-2999.3795894322757, z dim=0.0,score = -2999.380 (best = 265485.193), noise_scale = 0.1
# Episode =  407, episode_reward=-2996.163592615877, z dim=0.0,score = -2996.164 (best = 265485.193), noise_scale = 0.1
# Episode =  408, episode_reward=-993.9035246402042, z dim=0.0,score = -993.904 (best = 265485.193), noise_scale = 0.1
# Episode =  409, episode_reward=-2998.9028779965865, z dim=0.0,score = -2998.903 (best = 265485.193), noise_scale = 0.1
# Episode =  410, episode_reward=-1999.275634173206, z dim=0.0,score = -1999.276 (best = 265485.193), noise_scale = 0.1
# Episode =  411, episode_reward=-2996.804600890379, z dim=0.0,score = -2996.805 (best = 265485.193), noise_scale = 0.1
# Episode =  412, episode_reward=-1995.3488466834237, z dim=0.0,score = -1995.349 (best = 265485.193), noise_scale = 0.1
# Episode =  413, episode_reward=-2999.2534307744595, z dim=0.0,score = -2999.253 (best = 265485.193), noise_scale = 0.1
# Episode =  414, episode_reward=-1997.5449349835076, z dim=0.0,score = -1997.545 (best = 265485.193), noise_scale = 0.1
# Episode =  415, episode_reward=-998.7013040352927, z dim=0.0,score = -998.701 (best = 265485.193), noise_scale = 0.1
# Episode =  416, episode_reward=-999.6703566094174, z dim=0.0,score = -999.670 (best = 265485.193), noise_scale = 0.1
# Episode =  417, episode_reward=-994.0322607364545, z dim=0.0,score = -994.032 (best = 265485.193), noise_scale = 0.1
# Episode =  418, episode_reward=-999.4839052799599, z dim=0.0,score = -999.484 (best = 265485.193), noise_scale = 0.1
# Episode =  419, episode_reward=-1997.4198309943472, z dim=0.0,score = -1997.420 (best = 265485.193), noise_scale = 0.1
# ...
# Episode = 4866, episode_reward=-2999.8272103105555, z dim=0.0,score = -2999.827 (best = 265485.193), noise_scale = 0.1
# Episode = 4867, episode_reward=-1998.2587462017063, z dim=0.0,score = -1998.259 (best = 265485.193), noise_scale = 0.1
# Episode = 4868, episode_reward=-2999.790583995416, z dim=0.0,score = -2999.791 (best = 265485.193), noise_scale = 0.1
# Episode = 4869, episode_reward=-2999.791144358269, z dim=0.0,score = -2999.791 (best = 265485.193), noise_scale = 0.1
# Episode = 4870, episode_reward=-2999.823580324747, z dim=0.0,score = -2999.824 (best = 265485.193), noise_scale = 0.1
# Episode = 4871, episode_reward=-2999.72793419847, z dim=0.0,score = -2999.728 (best = 265485.193), noise_scale = 0.1
# Episode = 4872, episode_reward=-2999.8151117741236, z dim=0.0,score = -2999.815 (best = 265485.193), noise_scale = 0.1
# Episode = 4873, episode_reward=-999.8541622688363, z dim=0.0,score = -999.854 (best = 265485.193), noise_scale = 0.1
# Episode = 4874, episode_reward=-2999.7194633666977, z dim=0.0,score = -2999.719 (best = 265485.193), noise_scale = 0.1
# Episode = 4875, episode_reward=-2999.7890503254357, z dim=0.0,score = -2999.789 (best = 265485.193), noise_scale = 0.1
# Episode = 4876, episode_reward=-999.8495235222999, z dim=0.0,score = -999.850 (best = 265485.193), noise_scale = 0.1
# Episode = 4877, episode_reward=-999.8533736299479, z dim=0.0,score = -999.853 (best = 265485.193), noise_scale = 0.1
# Episode = 4878, episode_reward=-2999.7649849247427, z dim=0.0,score = -2999.765 (best = 265485.193), noise_scale = 0.1
# Episode = 4879, episode_reward=-2999.8202854917595, z dim=0.0,score = -2999.820 (best = 265485.193), noise_scale = 0.1
# Episode = 4880, episode_reward=-2999.7195320396913, z dim=0.0,score = -2999.720 (best = 265485.193), noise_scale = 0.1
# Episode = 4881, episode_reward=-2999.8256197236415, z dim=0.0,score = -2999.826 (best = 265485.193), noise_scale = 0.1
# Episode = 4882, episode_reward=-2999.7233709189477, z dim=0.0,score = -2999.723 (best = 265485.193), noise_scale = 0.1
# Episode = 4883, episode_reward=-2999.7275885269064, z dim=0.0,score = -2999.728 (best = 265485.193), noise_scale = 0.1
# Episode = 4884, episode_reward=-2999.7854806334167, z dim=0.0,score = -2999.785 (best = 265485.193), noise_scale = 0.1
# Episode = 4885, episode_reward=-999.8621672552405, z dim=0.0,score = -999.862 (best = 265485.193), noise_scale = 0.1
# Episode = 4886, episode_reward=-999.8700066013621, z dim=0.0,score = -999.870 (best = 265485.193), noise_scale = 0.1
# Episode = 4887, episode_reward=-2999.833161512007, z dim=0.0,score = -2999.833 (best = 265485.193), noise_scale = 0.1
# Episode = 4888, episode_reward=-2999.730525042864, z dim=0.0,score = -2999.731 (best = 265485.193), noise_scale = 0.1
# Episode = 4889, episode_reward=-999.8771918871629, z dim=0.0,score = -999.877 (best = 265485.193), noise_scale = 0.1
# Episode = 4890, episode_reward=-1999.5640277386337, z dim=0.0,score = -1999.564 (best = 265485.193), noise_scale = 0.1
# Episode = 4891, episode_reward=-999.8576927752637, z dim=0.0,score = -999.858 (best = 265485.193), noise_scale = 0.1
# Episode = 4892, episode_reward=-1999.6527330316778, z dim=0.0,score = -1999.653 (best = 265485.193), noise_scale = 0.1
# Episode = 4893, episode_reward=-2999.7979658163936, z dim=0.0,score = -2999.798 (best = 265485.193), noise_scale = 0.1
# Episode = 4894, episode_reward=-999.8697053103597, z dim=0.0,score = -999.870 (best = 265485.193), noise_scale = 0.1
# Episode = 4895, episode_reward=-2999.815474958857, z dim=0.0,score = -2999.815 (best = 265485.193), noise_scale = 0.1
# Episode = 4896, episode_reward=-999.8623888494184, z dim=0.0,score = -999.862 (best = 265485.193), noise_scale = 0.1
# Episode = 4897, episode_reward=-999.8577793947694, z dim=0.0,score = -999.858 (best = 265485.193), noise_scale = 0.1
# Episode = 4898, episode_reward=-2999.7383793378185, z dim=0.0,score = -2999.738 (best = 265485.193), noise_scale = 0.1
# Episode = 4899, episode_reward=-999.8636605741433, z dim=0.0,score = -999.864 (best = 265485.193), noise_scale = 0.1
# Episode = 4900, episode_reward=-2999.837640390106, z dim=0.0,score = -2999.838 (best = 265485.193), noise_scale = 0.1
# Episode = 4901, episode_reward=-2999.7967213541315, z dim=0.0,score = -2999.797 (best = 265485.193), noise_scale = 0.1
# Episode = 4902, episode_reward=-999.8663359185921, z dim=0.0,score = -999.866 (best = 265485.193), noise_scale = 0.1
# Episode = 4903, episode_reward=-999.8456988614896, z dim=0.0,score = -999.846 (best = 265485.193), noise_scale = 0.1
# Episode = 4904, episode_reward=-2999.8306773859267, z dim=0.0,score = -2999.831 (best = 265485.193), noise_scale = 0.1
# Episode = 4905, episode_reward=-999.848123664312, z dim=0.0,score = -999.848 (best = 265485.193), noise_scale = 0.1
# Episode = 4906, episode_reward=-1987.3036828492593, z dim=0.0,score = -1987.304 (best = 265485.193), noise_scale = 0.1
# Episode = 4907, episode_reward=-2999.843872835495, z dim=0.0,score = -2999.844 (best = 265485.193), noise_scale = 0.1
# Episode = 4908, episode_reward=-999.8677316191198, z dim=0.0,score = -999.868 (best = 265485.193), noise_scale = 0.1
# Episode = 4909, episode_reward=-2999.8029182791397, z dim=0.0,score = -2999.803 (best = 265485.193), noise_scale = 0.1
# Episode = 4910, episode_reward=-999.8573530034682, z dim=0.0,score = -999.857 (best = 265485.193), noise_scale = 0.1
# Episode = 4911, episode_reward=-999.8626860505294, z dim=0.0,score = -999.863 (best = 265485.193), noise_scale = 0.1
# Episode = 4912, episode_reward=-2999.728884517818, z dim=0.0,score = -2999.729 (best = 265485.193), noise_scale = 0.1
# Episode = 4913, episode_reward=-999.8717933554074, z dim=0.0,score = -999.872 (best = 265485.193), noise_scale = 0.1
# Episode = 4914, episode_reward=-2999.8127993308194, z dim=0.0,score = -2999.813 (best = 265485.193), noise_scale = 0.1
# Episode = 4915, episode_reward=-999.8674905463338, z dim=0.0,score = -999.867 (best = 265485.193), noise_scale = 0.1
# Episode = 4916, episode_reward=-999.8490772594299, z dim=0.0,score = -999.849 (best = 265485.193), noise_scale = 0.1
# Episode = 4917, episode_reward=-2999.839779095193, z dim=0.0,score = -2999.840 (best = 265485.193), noise_scale = 0.1
# Episode = 4918, episode_reward=-2999.803399144612, z dim=0.0,score = -2999.803 (best = 265485.193), noise_scale = 0.1
# Episode = 4919, episode_reward=-999.8651406128461, z dim=0.0,score = -999.865 (best = 265485.193), noise_scale = 0.1
# Episode = 4920, episode_reward=-1999.5719132445793, z dim=0.0,score = -1999.572 (best = 265485.193), noise_scale = 0.1
# Episode = 4921, episode_reward=-999.851853921944, z dim=0.0,score = -999.852 (best = 265485.193), noise_scale = 0.1
# Episode = 4922, episode_reward=-999.8560662246845, z dim=0.0,score = -999.856 (best = 265485.193), noise_scale = 0.1
# Episode = 4923, episode_reward=-999.8474911366673, z dim=0.0,score = -999.847 (best = 265485.193), noise_scale = 0.1
# Episode = 4924, episode_reward=-999.8517392480996, z dim=0.0,score = -999.852 (best = 265485.193), noise_scale = 0.1
# Episode = 4925, episode_reward=-999.8622811358229, z dim=0.0,score = -999.862 (best = 265485.193), noise_scale = 0.1
# Episode = 4926, episode_reward=-2999.7096784431783, z dim=0.0,score = -2999.710 (best = 265485.193), noise_scale = 0.1
# Episode = 4927, episode_reward=-2989.1290646892653, z dim=0.0,score = -2989.129 (best = 265485.193), noise_scale = 0.1
# Episode = 4928, episode_reward=-999.850315697673, z dim=0.0,score = -999.850 (best = 265485.193), noise_scale = 0.1
# Episode = 4929, episode_reward=-2999.761171885483, z dim=0.0,score = -2999.761 (best = 265485.193), noise_scale = 0.1
# Episode = 4930, episode_reward=-2999.838463543464, z dim=0.0,score = -2999.838 (best = 265485.193), noise_scale = 0.1
# Episode = 4931, episode_reward=-999.853715866093, z dim=0.0,score = -999.854 (best = 265485.193), noise_scale = 0.1
# Episode = 4932, episode_reward=-999.85191491416, z dim=0.0,score = -999.852 (best = 265485.193), noise_scale = 0.1
# Episode = 4933, episode_reward=-999.8738936035602, z dim=0.0,score = -999.874 (best = 265485.193), noise_scale = 0.1
# Episode = 4934, episode_reward=-999.8461307510103, z dim=0.0,score = -999.846 (best = 265485.193), noise_scale = 0.1
# Episode = 4935, episode_reward=-2999.7106106369047, z dim=0.0,score = -2999.711 (best = 265485.193), noise_scale = 0.1
# Episode = 4936, episode_reward=-999.8499074549418, z dim=0.0,score = -999.850 (best = 265485.193), noise_scale = 0.1
# Episode = 4937, episode_reward=-2999.8045551187975, z dim=0.0,score = -2999.805 (best = 265485.193), noise_scale = 0.1
# Episode = 4938, episode_reward=-999.8504604318218, z dim=0.0,score = -999.850 (best = 265485.193), noise_scale = 0.1
# Episode = 4939, episode_reward=-2999.8359539786056, z dim=0.0,score = -2999.836 (best = 265485.193), noise_scale = 0.1
# Episode = 4940, episode_reward=-2999.8354169017375, z dim=0.0,score = -2999.835 (best = 265485.193), noise_scale = 0.1
# Episode = 4941, episode_reward=-2999.740180482643, z dim=0.0,score = -2999.740 (best = 265485.193), noise_scale = 0.1
# Episode = 4942, episode_reward=-2999.8224375840064, z dim=0.0,score = -2999.822 (best = 265485.193), noise_scale = 0.1
# Episode = 4943, episode_reward=-999.851851397909, z dim=0.0,score = -999.852 (best = 265485.193), noise_scale = 0.1
# Episode = 4944, episode_reward=-2999.824655505728, z dim=0.0,score = -2999.825 (best = 265485.193), noise_scale = 0.1
# Episode = 4945, episode_reward=-999.8598231672452, z dim=0.0,score = -999.860 (best = 265485.193), noise_scale = 0.1
# Episode = 4946, episode_reward=-2999.7273955112933, z dim=0.0,score = -2999.727 (best = 265485.193), noise_scale = 0.1
# Episode = 4947, episode_reward=-999.8745975029664, z dim=0.0,score = -999.875 (best = 265485.193), noise_scale = 0.1
# Episode = 4948, episode_reward=-2999.818197343647, z dim=0.0,score = -2999.818 (best = 265485.193), noise_scale = 0.1
# Episode = 4949, episode_reward=-2999.785159446649, z dim=0.0,score = -2999.785 (best = 265485.193), noise_scale = 0.1
# Episode = 4950, episode_reward=-999.8489403955981, z dim=0.0,score = -999.849 (best = 265485.193), noise_scale = 0.1
# Episode = 4951, episode_reward=-2999.83203080135, z dim=0.0,score = -2999.832 (best = 265485.193), noise_scale = 0.1
# Episode = 4952, episode_reward=-2999.7376896379187, z dim=0.0,score = -2999.738 (best = 265485.193), noise_scale = 0.1
# Episode = 4953, episode_reward=-2999.7952967467018, z dim=0.0,score = -2999.795 (best = 265485.193), noise_scale = 0.1
# Episode = 4954, episode_reward=-999.5220680105402, z dim=0.0,score = -999.522 (best = 265485.193), noise_scale = 0.1
# Episode = 4955, episode_reward=-999.8609879480664, z dim=0.0,score = -999.861 (best = 265485.193), noise_scale = 0.1
# Episode = 4956, episode_reward=-999.8677588379879, z dim=0.0,score = -999.868 (best = 265485.193), noise_scale = 0.1
# Episode = 4957, episode_reward=-999.8479486468513, z dim=0.0,score = -999.848 (best = 265485.193), noise_scale = 0.1
# Episode = 4958, episode_reward=-2999.6872337784957, z dim=0.0,score = -2999.687 (best = 265485.193), noise_scale = 0.1
# Episode = 4959, episode_reward=-999.853881910041, z dim=0.0,score = -999.854 (best = 265485.193), noise_scale = 0.1
# Episode = 4960, episode_reward=-999.8472103243403, z dim=0.0,score = -999.847 (best = 265485.193), noise_scale = 0.1
# Episode = 4961, episode_reward=-999.8474907530202, z dim=0.0,score = -999.847 (best = 265485.193), noise_scale = 0.1
# Episode = 4962, episode_reward=-999.8608482191244, z dim=0.0,score = -999.861 (best = 265485.193), noise_scale = 0.1
# Episode = 4963, episode_reward=-999.8700602938925, z dim=0.0,score = -999.870 (best = 265485.193), noise_scale = 0.1
# Episode = 4964, episode_reward=-999.8519248614829, z dim=0.0,score = -999.852 (best = 265485.193), noise_scale = 0.1
# Episode = 4965, episode_reward=-2999.8119345926593, z dim=0.0,score = -2999.812 (best = 265485.193), noise_scale = 0.1
# Episode = 4966, episode_reward=-2999.8378984859796, z dim=0.0,score = -2999.838 (best = 265485.193), noise_scale = 0.1
# Episode = 4967, episode_reward=-2999.767158431951, z dim=0.0,score = -2999.767 (best = 265485.193), noise_scale = 0.1
# Episode = 4968, episode_reward=-2999.783010531456, z dim=0.0,score = -2999.783 (best = 265485.193), noise_scale = 0.1
# Episode = 4969, episode_reward=-2999.7901009176153, z dim=0.0,score = -2999.790 (best = 265485.193), noise_scale = 0.1
# Episode = 4970, episode_reward=-999.8676678806829, z dim=0.0,score = -999.868 (best = 265485.193), noise_scale = 0.1
# Episode = 4971, episode_reward=-999.865882185391, z dim=0.0,score = -999.866 (best = 265485.193), noise_scale = 0.1
# Episode = 4972, episode_reward=-999.8513308216438, z dim=0.0,score = -999.851 (best = 265485.193), noise_scale = 0.1
# Episode = 4973, episode_reward=-2999.8061910803485, z dim=0.0,score = -2999.806 (best = 265485.193), noise_scale = 0.1
# Episode = 4974, episode_reward=-2999.8255142488697, z dim=0.0,score = -2999.826 (best = 265485.193), noise_scale = 0.1
# Episode = 4975, episode_reward=-999.8507787008094, z dim=0.0,score = -999.851 (best = 265485.193), noise_scale = 0.1
# Episode = 4976, episode_reward=-999.8531899769306, z dim=0.0,score = -999.853 (best = 265485.193), noise_scale = 0.1
# Episode = 4977, episode_reward=-999.8513819947145, z dim=0.0,score = -999.851 (best = 265485.193), noise_scale = 0.1
# Episode = 4978, episode_reward=-2999.7842816950483, z dim=0.0,score = -2999.784 (best = 265485.193), noise_scale = 0.1
# Episode = 4979, episode_reward=-2999.8236220722483, z dim=0.0,score = -2999.824 (best = 265485.193), noise_scale = 0.1
# Episode = 4980, episode_reward=-2999.7410227335718, z dim=0.0,score = -2999.741 (best = 265485.193), noise_scale = 0.1
# Episode = 4981, episode_reward=-2999.7809062235283, z dim=0.0,score = -2999.781 (best = 265485.193), noise_scale = 0.1
# Episode = 4982, episode_reward=-1999.855496005836, z dim=0.001018366933359233,score = -1999.855 (best = 265485.193), noise_scale = 0.1
# Episode = 4983, episode_reward=-999.8539200793978, z dim=0.0,score = -999.854 (best = 265485.193), noise_scale = 0.1
# Episode = 4984, episode_reward=-999.8619890715253, z dim=0.0,score = -999.862 (best = 265485.193), noise_scale = 0.1
# Episode = 4985, episode_reward=-1999.6524701456483, z dim=0.0,score = -1999.652 (best = 265485.193), noise_scale = 0.1
# Episode = 4986, episode_reward=-999.8570575217027, z dim=0.0,score = -999.857 (best = 265485.193), noise_scale = 0.1
# Episode = 4987, episode_reward=-999.8645042470213, z dim=0.0,score = -999.865 (best = 265485.193), noise_scale = 0.1
# Episode = 4988, episode_reward=-999.8484348193033, z dim=0.0,score = -999.848 (best = 265485.193), noise_scale = 0.1
# Episode = 4989, episode_reward=-2999.804483801589, z dim=0.0,score = -2999.804 (best = 265485.193), noise_scale = 0.1
# Episode = 4990, episode_reward=-999.8505705326539, z dim=0.0,score = -999.851 (best = 265485.193), noise_scale = 0.1
# Episode = 4991, episode_reward=-2999.812817509188, z dim=0.0,score = -2999.813 (best = 265485.193), noise_scale = 0.1
# Episode = 4992, episode_reward=-2999.796817132301, z dim=0.0,score = -2999.797 (best = 265485.193), noise_scale = 0.1
# Episode = 4993, episode_reward=-2999.776915779563, z dim=0.0,score = -2999.777 (best = 265485.193), noise_scale = 0.1
# Episode = 4994, episode_reward=-999.8757957269464, z dim=0.0,score = -999.876 (best = 265485.193), noise_scale = 0.1
# Episode = 4995, episode_reward=-999.8521810921543, z dim=0.0,score = -999.852 (best = 265485.193), noise_scale = 0.1
# Episode = 4996, episode_reward=-999.8473493620397, z dim=0.0,score = -999.847 (best = 265485.193), noise_scale = 0.1
# Episode = 4997, episode_reward=-2999.7635988940997, z dim=0.0,score = -2999.764 (best = 265485.193), noise_scale = 0.1
# Episode = 4998, episode_reward=-2999.7025077087023, z dim=0.0,score = -2999.703 (best = 265485.193), noise_scale = 0.1
# Episode = 4999, episode_reward=-2999.7821574968643, z dim=0.0,score = -2999.782 (best = 265485.193), noise_scale = 0.1
# Episode = 5000, episode_reward=-999.8496076275978, z dim=0.0,score = -999.850 (best = 265485.193), noise_scale = 0.1

# %% [markdown]
# ## Plot the Rewards
#
# Once you are satisfied with your performance, plot the episode rewards, either from a single run, or averaged over multiple runs.

# %%
plt.plot(rewards, label='rewards')

# %%
plt.plot(z, label='z by episode')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

## TODO: Plot the rewards.
# plt.plot(rewards,x, label='x vs rewards')
# plt.plot(rewards,y, label='y vs rewards')
plt.plot(rewards,z, label='rewards vs z')

plt.legend()
_ = plt.ylim()

# %% [markdown]
# Reference:
#
# https://hal.archives-ouvertes.fr/hal-00331752/document
#
# https://www.quora.com/What-are-the-benefits-of-actor-critic-framework-in-reinforcement-learning
#
# https://robotics.stackexchange.com/questions/1266/what-reward-function-results-in-optimal-learning
#
# https://towardsdatascience.com/estimating-optimal-learning-rate-for-a-deep-neural-network-ce32f2556ce0

# %% [markdown]
# ## Reflections
#
# **Question 1**: Describe the task that you specified in `task.py`.  How did you design the reward function?
#
# **Answer**: I chose "takeoff" task. As this is my first attempt to built reward function in continuous space, I chose to focus on vertical distance for the time being. I used step function i.e. if the vertical height is close to target, I gave it the most point. If it was outside of 25 vertical distance, I reduced the reward and also added penalty.

# %% [markdown]
# **Question 2**: Discuss your agent briefly, using the following questions as a guide:
#
# - What learning algorithm(s) did you try? What worked best for you?
# - What was your final choice of hyperparameters (such as $\alpha$, $\gamma$, $\epsilon$, etc.)?
# - What neural network architecture did you use (if any)? Specify layers, sizes, activation functions, etc.
#
# **Answer**: I only tried policy-gradient actor-critic algorithm popularly known as Deep Deterministic Policy Gradients
# Actor critic methods combine the best of Value based methods and policy search and gradient method.
#
# Final hyper parameters used are theta=0.15, sigma=0.2, gamma=0.95 and tau=0.001.
# For the actor model, 3 hidden layers (size 32,64 & 32 respectively) with relu activation and sigmoid activation in final layer.
#
#
# For the critic model 2 dense hidden layers(size 32 and 64 respectively) and relu activation function.
#
# Both model used a variation of stochastic gradient descent optimizer, Adam Optimizer with a default learning_rate=0.001.

# %% [markdown]
# **Question 3**: Using the episode rewards plot, discuss how the agent learned over time.
#
# - Was it an easy task to learn or hard?
# - Was there a gradual learning curve, or an aha moment?
# - How good was the final performance of the agent? (e.g. mean rewards over the last 10 episodes)
#
# **Answer**: The final performance still needs improvement. I have not been able to find the aha moment yet. Reward function is a challenging task in a continuos space and I am yet looking for the best reward function

# %% [markdown]
# **Question 4**: Briefly summarize your experience working on this project. You can use the following prompts for ideas.
#
# - What was the hardest part of the project? (e.g. getting started, plotting, specifying the task, etc.)
# - Did you find anything interesting in how the quadcopter or your agent behaved?
#
# **Answer**: The hardest part is creating the reward function. I started with just vertical lift off but there is so much more to add to the reward function, for example the x and y dimesion, and the euler angles as well.
