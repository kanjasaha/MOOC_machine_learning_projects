# %% [markdown]
# # Project: Train a Quadcopter How to Fly
#
# Design an agent to fly a quadcopter, and then train it using a reinforcement learning algorithm of your choice!
#
# Try to apply the techniques you have learnt, but also feel free to come up with innovative ideas and test them.

# %% [markdown]
# ## Instructions
#
# Take a look at the files in the directory to better understand the structure of the project.
#
# - `task.py`: Define your task (environment) in this file.
# - `agents/`: Folder containing reinforcement learning agents.
#     - `policy_search.py`: A sample agent has been provided here.
#     - `agent.py`: Develop your agent here.
# - `physics_sim.py`: This file contains the simulator for the quadcopter.  **DO NOT MODIFY THIS FILE**.
#
# For this project, you will define your own task in `task.py`.  Although we have provided a example task to get you started, you are encouraged to change it.  Later in this notebook, you will learn more about how to amend this file.
#
# You will also design a reinforcement learning agent in `agent.py` to complete your chosen task.
#
# You are welcome to create any additional files to help you to organize your code.  For instance, you may find it useful to define a `model.py` file defining any needed neural network architectures.
#
# ## Controlling the Quadcopter
#
# We provide a sample agent in the code cell below to show you how to use the sim to control the quadcopter.  This agent is even simpler than the sample agent that you'll examine (in `agents/policy_search.py`) later in this notebook!
#
# The agent controls the quadcopter by setting the revolutions per second on each of its four rotors.  The provided agent in the `Basic_Agent` class below always selects a random action for each of the four rotors.  These four speeds are returned by the `act` method as a list of four floating-point numbers.
#
# For this project, the agent that you will implement in `agents/agent.py` will have a far more intelligent method for selecting actions!

# %%
import random

class Basic_Agent():
    def __init__(self, task):
        self.task = task
    
    def act(self):
        new_thrust = random.gauss(450., 25.)
        return [new_thrust + random.gauss(0.
                                          , 1.) for x in range(4)]

# %% [markdown]
# Run the code cell below to have the agent select actions to control the quadcopter.
#
# Feel free to change the provided values of `runtime`, `init_pose`, `init_velocities`, and `init_angle_velocities` below to change the starting conditions of the quadcopter.
#
# The `labels` list below annotates statistics that are saved while running the simulation.  All of this information is saved in a text file `data.txt` and stored in the dictionary `results`.

# %%
# %load_ext autoreload
# %autoreload 2

import csv
import numpy as np
from task import Task

# Modify the values below to give the quadcopter a different starting position.
runtime = 10.                                     # time limit of the episode
init_pose = np.array([0., 0., 10., 0., 0., 0.])  # initial pose
init_velocities = np.array([0., 0., 0.])         # initial velocities
init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities
file_output = 'data.txt'                         # file name for saved results

# Setup
task = Task(init_pose, init_velocities, init_angle_velocities, runtime)
agent = Basic_Agent(task)
done = False
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

# Run the simulation, and save the results.
with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    while True:
        rotor_speeds = agent.act()
        _, _, done = task.step(rotor_speeds)
        to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
        for ii in range(len(labels)):
            results[labels[ii]].append(to_write[ii])
        writer.writerow(to_write)
        if done:
            break

# %% [markdown]
# Run the code cell below to visualize how the position of the quadcopter evolved during the simulation.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(results['time'], results['x'], label='x')
plt.plot(results['time'], results['y'], label='y')
plt.plot(results['time'], results['z'], label='z')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# The next code cell visualizes the velocity of the quadcopter.

# %%
plt.plot(results['time'], results['x_velocity'], label='x_hat')
plt.plot(results['time'], results['y_velocity'], label='y_hat')
plt.plot(results['time'], results['z_velocity'], label='z_hat')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Next, you can plot the Euler angles (the rotation of the quadcopter over the $x$-, $y$-, and $z$-axes),

# %%
plt.plot(results['time'], results['phi'], label='phi')
plt.plot(results['time'], results['theta'], label='theta')
plt.plot(results['time'], results['psi'], label='psi')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# before plotting the velocities (in radians per second) corresponding to each of the Euler angles.

# %%
plt.plot(results['time'], results['phi_velocity'], label='phi_velocity')
plt.plot(results['time'], results['theta_velocity'], label='theta_velocity')
plt.plot(results['time'], results['psi_velocity'], label='psi_velocity')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Finally, you can use the code cell below to print the agent's choice of actions.

# %%
plt.plot(results['time'], results['rotor_speed1'], label='Rotor 1 revolutions / second')
plt.plot(results['time'], results['rotor_speed2'], label='Rotor 2 revolutions / second')
plt.plot(results['time'], results['rotor_speed3'], label='Rotor 3 revolutions / second')
plt.plot(results['time'], results['rotor_speed4'], label='Rotor 4 revolutions / second')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# When specifying a task, you will derive the environment state from the simulator.  Run the code cell below to print the values of the following variables at the end of the simulation:
# - `task.sim.pose` (the position of the quadcopter in ($x,y,z$) dimensions and the Euler angles),
# - `task.sim.v` (the velocity of the quadcopter in ($x,y,z$) dimensions), and
# - `task.sim.angular_v` (radians/second for each of the three Euler angles).

# %%
# the pose, velocity, and angular velocity of the quadcopter at the end of the episode
print(task.sim.pose)
print(task.sim.v)
print(task.sim.angular_v)
# Out:
# [-56.76151184  22.84932408   0.           0.72232876   1.22717919   0.        ]
# [-22.89408738  -0.73116732 -22.17321014]
# [ 0.02929206  0.10306254  0.        ]

# %% [markdown]
# In the sample task in `task.py`, we use the 6-dimensional pose of the quadcopter to construct the state of the environment at each timestep.  However, when amending the task for your purposes, you are welcome to expand the size of the state vector by including the velocity information.  You can use any combination of the pose, velocity, and angular velocity - feel free to tinker here, and construct the state to suit your task.
#
# ## The Task
#
# A sample task has been provided for you in `task.py`.  Open this file in a new window now.
#
# The `__init__()` method is used to initialize several variables that are needed to specify the task.
# - The simulator is initialized as an instance of the `PhysicsSim` class (from `physics_sim.py`).
# - Inspired by the methodology in the original DDPG paper, we make use of action repeats.  For each timestep of the agent, we step the simulation `action_repeats` timesteps.  If you are not familiar with action repeats, please read the **Results** section in [the DDPG paper](https://arxiv.org/abs/1509.02971).
# - We set the number of elements in the state vector.  For the sample task, we only work with the 6-dimensional pose information.  To set the size of the state (`state_size`), we must take action repeats into account.
# - The environment will always have a 4-dimensional action space, with one entry for each rotor (`action_size=4`). You can set the minimum (`action_low`) and maximum (`action_high`) values of each entry here.
# - The sample task in this provided file is for the agent to reach a target position.  We specify that target position as a variable.
#
# The `reset()` method resets the simulator.  The agent should call this method every time the episode ends.  You can see an example of this in the code cell below.
#
# The `step()` method is perhaps the most important.  It accepts the agent's choice of action `rotor_speeds`, which is used to prepare the next state to pass on to the agent.  Then, the reward is computed from `get_reward()`.  The episode is considered done if the time limit has been exceeded, or the quadcopter has travelled outside of the bounds of the simulation.
#
# In the next section, you will learn how to test the performance of an agent on this task.

# %% [markdown]
# ## The Agent
#
# The sample agent given in `agents/policy_search.py` uses a very simplistic linear policy to directly compute the action vector as a dot product of the state vector and a matrix of weights. Then, it randomly perturbs the parameters by adding some Gaussian noise, to produce a different policy. Based on the average reward obtained in each episode (`score`), it keeps track of the best set of parameters found so far, how the score is changing, and accordingly tweaks a scaling factor to widen or tighten the noise.
#
# Run the code cell below to see how the agent performs on the sample task.

# %%
import sys
import pandas as pd
from agents.policy_search import PolicySearch_Agent
from task import Task

num_episodes = 5
target_pos = np.array([0., 0., 10.])
task = Task(target_pos=target_pos)
agent = PolicySearch_Agent(task) 

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
#     print('notebook right after resent')
#     print(state)
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        agent.step(reward, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
                i_episode, agent.score, agent.best_score, agent.noise_scale), end="")  # [debug]
            break
    sys.stdout.flush()
# Out:
# Episode =    5, score =  -2.148 (best =  -0.697), noise_scale = 0.055

# %% [markdown]
# This agent should perform very poorly on this task.  And that's where you come in!

# %% [markdown]
# ## Define the Task, Design the Agent, and Train Your Agent!
#
# Amend `task.py` to specify a task of your choosing.  If you're unsure what kind of task to specify, you may like to teach your quadcopter to takeoff, hover in place, land softly, or reach a target pose.
#
# After specifying your task, use the sample agent in `agents/policy_search.py` as a template to define your own agent in `agents/agent.py`.  You can borrow whatever you need from the sample agent, including ideas on how you might modularize your code (using helper methods like `act()`, `learn()`, `reset_episode()`, etc.).
#
# Note that it is **highly unlikely** that the first agent and task that you specify will learn well.  You will likely have to tweak various hyperparameters and the reward function for your task until you arrive at reasonably good behavior.
#
# As you develop your agent, it's important to keep an eye on how it's performing. Use the code above as inspiration to build in a mechanism to log/save the total rewards obtained in each episode to file.  If the episode rewards are gradually increasing, this is an indication that your agent is learning.

# %%
# %load_ext autoreload
# %autoreload 2

import csv
import numpy as np
from task_takeoff import Task_TakeOff
from agents.agent_takeoff import Agent_TakeOff

# Modify the values below to give the quadcopter a different starting position.
runtime = 10.                                     # time limit of the episode
file_output = 'data2.txt'                         # file name for saved results

# Setup
done = False
labels1 = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3',
           'rotor_speed4','episode','reward']

results1 = {x : [] for x in labels1}


num_episodes = 500
# target_z = 100
# task = Task_TakeOff(runtime=runtime,target_z=target_z)
init_pos = np.array([0., 0., 0., 0., 0., 0.])
target_pos = np.array([0., 0., 100.])
task = Task_TakeOff(init_pose=init_pos, target_pos=target_pos,runtime=10.)
agent = Agent_TakeOff(task) 
with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels1)

    for i_episode in range(1, num_episodes+1):
        state = agent.reset_episode() # start a new episode
#         print('notebook right after resent')
#         print(state)

        while True:
#             print('calling from notebook')
            action = agent.act(state) 
#             print('------')
            #print(i_episode)
            next_state, reward, done = task.step(action)
            agent.step(reward, done)
            #agent.step(action, reward, next_state, done)
            state = next_state
            #to_write = [i_episode] + [reward]
            to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)+[i_episode] + [reward]
#             print('to_write')
#             print(to_write)
             
        
            for ii in range(len(labels1)):
                results1[labels1[ii]].append(to_write[ii])
            
#             print(i_episode)
            
               
            if done:
                writer.writerow(to_write)
                print('Score')
                print("\rEpisode = {:4d}, v_dimension={}, score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
                    i_episode,task.sim.pose ,agent.score, agent.best_score, agent.noise_scale), end="")  # [debug]
                break


        #sys.stdout.flush()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Score
# Episode =    1, v_dimension=[ 0.  0.  0.  0.  0.  0.], score =    -inf (best =    -inf), noise_scale = 0.1Score
# Episode =    2, v_dimension=[ 0.  0.  0.  0.  0.  0.], score =    -inf (best =    -inf), noise_scale = 0.1Score
# Episode =    3, v_dimension=[ 0.  0.  0.  0.  0.  0.], score =    -inf (best =    -inf), noise_scale = 0.1Score
# Episode =    4, v_dimension=[ 0.  0.  0.  0.  0.  0.], score =    -inf (best =    -inf), noise_scale = 0.1Score
# Episode =    5, v_dimension=[ 0.  0.  0.  0.  0.  0.], score =    -inf (best =    -inf), noise_scale = 0.1Score
# Episode =    6, v_dimension=[ 0.  0.  0.  0.  0.  0.], score =    -inf (best =    -inf), noise_scale = 0.1Score
# Episode =    7, v_dimension=[ 0.  0.  0.  0.  0.  0.], score =    -inf (best =    -inf), noise_scale = 0.1Score
# Episode =    8, v_dimension=[ 0.  0.  0.  0.  0.  0.], score =    -inf (best =    -inf), noise_scale = 0.1Score
# Episode =    9, v_dimension=[ 0.  0.  0.  0.  0.  0.], score =    -inf (best =    -inf), noise_scale = 0.1Score
# Episode =   10, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 10Score
# Episode =   11, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 10Score
# Episode =   12, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 10Score
# Episode =   13, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 10Score
# Episode =   14, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 10Score
# Episode =   15, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 10Score
# Episode =   16, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 10Score
# Episode =   17, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 10Score
# Episode =   18, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 10Score
# Episode =   19, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 10Score
# Episode =   20, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   21, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   22, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   23, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   24, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   25, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   26, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   27, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   28, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   29, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   30, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   31, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   32, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   33, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   34, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   35, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   36, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   37, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   38, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   39, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   40, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   41, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   42, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   43, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   44, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   45, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   46, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   47, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   48, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   49, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   50, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   51, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   52, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   53, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   54, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   55, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   56, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   57, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   58, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   59, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   60, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   61, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   62, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   63, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   64, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   65, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   66, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   67, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   68, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   69, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   70, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   71, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   72, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   73, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   74, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   75, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   76, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   77, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   78, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   79, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   80, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   81, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   82, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   83, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   84, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   85, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   86, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   87, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   88, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   89, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   90, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   91, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   92, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   93, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =   94, v_dimension=[ 0.  0.  0.  0.  0.  0.], score = 294.000 (best = 294.000), noise_scale = 0.1Score
# Episode =